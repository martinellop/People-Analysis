# %%
# !python .\moveFiles.py

# %%
# !python .\generateDatasetFeatures.py
# Out:
# C:\Users\Leonardo\Documents\Universita\CVCS\PRJ\reid\CelebREID_empty\CelebREID_empty\datasetProva\pedestrianUnito
# => Loaded checkpoint 'C:\Users\Leonardo\Documents\Universita\CVCS\PRJ\reid\CelebREID_empty\model.pth.tar'
# Start extracting features...
#
# name:  ['092_001.jpg', '092_007.jpg', '092_022.jpg', '092_025.jpg']
# torch.Size([4, 1024])
# name:  ['092_028.jpg', '092_035.jpg', '092_037.jpg', '092_040.jpg']
# torch.Size([8, 1024])
# name:  ['092_055.jpg', '092_066.jpg', '092_070.jpg', '092_100.jpg']
# torch.Size([12, 1024])
# name:  ['092_109.jpg', '092_154.jpg', '092_157.jpg', '092_163.jpg']
# torch.Size([16, 1024])
# name:  ['092_166.jpg', '092_169.jpg', '092_199.jpg', '092_206.jpg']
# torch.Size([20, 1024])
# name:  ['092_227.jpg', '092_256.jpg', '092_298.jpg', '092_304.jpg']
# torch.Size([24, 1024])
# name:  ['092_313.jpg', '092_324.jpg', '092_331.jpg', '092_376.jpg']
# torch.Size([28, 1024])
# name:  ['092_415.jpg', '095_001.jpg', '095_010.jpg', '095_013.jpg']
# ...
